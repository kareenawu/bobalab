# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats
#from scipy.stats import norm
import sklearn
import statsmodels.api as sm

import datetime
# %matplotlib inline

#sns.set(style="dark")
plt.style.use("ggplot")
import json

# %%
from google.colab import files

#upload file of results that are downloaded from Qualtrics
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ab7ffcc1-838b-442a-a3da-dc4672ee424d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab7ffcc1-838b-442a-a3da-dc4672ee424d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#read file of results that are downloaded from Qualtrics into pd dataframe
df = pd.read_csv('Driving Game - iFrame Test_April 11, 2023_12.23.csv')
df = df.iloc[2:,:]
df.head()
# Out:
#              StartDate              EndDate      Status      IPAddress  \
# 2  2023-03-28 19:35:24  2023-03-28 20:53:04  IP Address   67.188.25.80
# 3  2023-03-28 21:13:22  2023-03-28 21:13:30  IP Address  216.4.115.200
# 4  2023-03-28 21:50:02  2023-03-28 21:50:05  IP Address  216.4.115.200
# 5  2023-03-29 17:19:45  2023-03-29 18:00:21  IP Address  173.79.37.112
# 6  2023-04-03 12:01:51  2023-04-03 12:35:44  IP Address     75.7.3.245
#
#   Progress Duration (in seconds) Finished         RecordedDate  \
# 2      100                  4660     True  2023-03-28 20:53:05
# 3      100                     7     True  2023-03-28 21:13:31
# 4      100                     3     True  2023-03-28 21:50:06
# 5      100                  2435     True  2023-03-29 18:00:21
# 6      100                  2032     True  2023-04-03 12:35:44
#
#           ResponseId RecipientLastName  ... Check - Left Check - Stop  \
# 2  R_5jvQWgUm177PTTr               NaN  ...          NaN          NaN
# ...

# %%
#Only pulls responses that have fully completed the game
completed = df[~df['Password Text'].isnull()]
completed
# Out:
#               StartDate              EndDate      Status        IPAddress  \
# 6   2023-04-03 12:01:51  2023-04-03 12:35:44  IP Address       75.7.3.245
# 7   2023-04-03 13:43:58  2023-04-03 16:02:50  IP Address     67.188.25.80
# 8   2023-04-03 19:31:32  2023-04-03 20:04:15  IP Address   192.31.105.233
# 9   2023-04-07 15:34:40  2023-04-07 16:04:45  IP Address  136.152.143.252
# 15  2023-04-11 11:53:34  2023-04-11 12:21:06  IP Address  135.180.194.108
#
#    Progress Duration (in seconds) Finished         RecordedDate  \
# 6       100                  2032     True  2023-04-03 12:35:44
# 7       100                  8331     True  2023-04-03 16:02:50
# 8       100                  1962     True  2023-04-03 20:04:15
# 9       100                  1805     True  2023-04-07 16:04:46
# 15      100                  1651     True  2023-04-11 12:21:07
#
#            ResponseId RecipientLastName  ... Check - Left Check - Stop  \
# ...

# %%
a = completed['Password Text'].iloc[0]

#translates json text in dataframe form
a_df = pd.DataFrame(eval(a))

# %%
#Saves Person A's data to CSV and downloads
a_df.to_csv('a.csv', encoding = 'utf-8-sig') 
files.download('a.csv')

# %%
#Saves Person B's data to CSV and downloads
b = completed['Password Text'].iloc[1]
b_df = pd.DataFrame(eval(b))

#translates json text in dataframe form
b_df.to_csv('b.csv', encoding = 'utf-8-sig') 
files.download('b.csv')

# %%
#Saves Person C's data to CSV and downloads
c = completed['Password Text'].iloc[2]
c_df = pd.DataFrame(eval(c))

#translates json text in dataframe form
c_df.to_csv('c.csv', encoding = 'utf-8-sig') 
files.download('c.csv')

# %%
#Saves Person D's data to CSV and downloads
d = completed['Password Text'].iloc[3]
d_df = pd.DataFrame(eval(d))

#translates json text in dataframe form
d_df.to_csv('d.csv', encoding = 'utf-8-sig') 
files.download('d.csv')

# %%
#Saves Person E's data to CSV and downloads
e = completed['Password Text'].iloc[4]
e_df = pd.DataFrame(eval(e))

#translates json text in dataframe form
e_df.to_csv('e.csv', encoding = 'utf-8-sig') 
files.download('e.csv')
